# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

# Local imports
from hat.utils.stability_testing import *

# %%
pv_dest_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/complementarity/pv_time_series'
wind_dest_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/complementarity/wind_time_series'
pv_filename_prefix = 'cf_pv_profile'
wind_filename_prefix = 'cf_wind_profile'

c_stab_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/complementarity/c_stab'
cf_mix_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/complementarity/cf_mix'
pearsons_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/complementarity/pearson'

rep_year_df = pd.read_csv('../data/misc/representative_year.csv')
years = range(2007,2014)

pv_wind_id_df = pd.read_csv('/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/misc/master_hydro_pv_wind.csv')

# build the base dataframe with the timestamps from 2012
rng = pd.date_range(f'2012-01-01 00:00:00+00:00', periods=8760, freq='1H')
base_df = pd.DataFrame()
base_df['dateTime'] = rng

# %%
pv_wind_id_df.head()
# Out:
#     start       end        lat         lon                   name  site_id  \
# 0  1/1/00  12/31/20  40.147715 -105.865879                 GRANBY  9019500
# 1  1/1/00  12/31/20  36.466670  -91.530000  MAMMOTH SPRINGS DAM 3  7069220
# 2  1/1/00  12/31/20  35.394714 -106.547531       JEMEZ CANYON DAM  8328950
# 3  1/1/00  12/31/20  41.475038  -79.445464           TIONESTA DAM  3020000
# 4  1/1/00  12/31/20  34.398667  -87.987939             Bear Creek  3592000
#
#                                    post_csv_filename    pv_id  wind_id  \
# 0  /Users/galljf/OneDrive - Idaho National Labora...  CO01656  CO01656
# 1                                                NaN  AR01157  AR01157
# 2  /Users/galljf/OneDrive - Idaho National Labora...  NM00003  NM00003
# 3  /Users/galljf/OneDrive - Idaho National Labora...  PA00110  PA00110
# 4  /Users/galljf/OneDrive - Idaho National Labora...  AL05903  AL05903
#
#    pv_wind_id_same
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True

# %% [markdown]
# # Complementarity PV-Hydro

# %%
from pathlib import Path
from scipy.stats import pearsonr

### Stability coefficient
missing_sites = []
df_missing = pd.DataFrame()

pv_wind_id_df.fillna(0, inplace=True)

pearsons_pv_hy = pd.DataFrame(columns=['site_id','p'])

annual_stab_df = pd.DataFrame(columns = ['site_id', 'lat', 'lon', 'c_stab'])

for idx, row in pv_wind_id_df.iterrows():

    if row['post_csv_filename'] == 0:
        print( f"No file for site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
    
    if row['site_id'] not in rep_year_df.site.values:
        print(f"Site doesn't have enough data: {row['site_id']}")
        empty_data_sites.append(row['site_id'])
        query_df.loc[idx,'post_csv_filename'] = ""
        continue
        
    print(f"{idx}. Processing PV profile {row['pv_id']} and NPD {row['site_id']}, {row['post_csv_filename']}")

    solar_df = pd.read_csv(f"{pv_dest_path}/{row['pv_id']}_{pv_filename_prefix}.csv",parse_dates=True,index_col=0)
    hydro_df = pd.read_csv(row['post_csv_filename'],parse_dates=True,index_col=0)
    
    hydro_df.fillna(0, inplace=True)
    
    if float(hydro_df['capacity_factor'].sum()) == 0.0:
        print( f"No data in site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
        
    cf_mix = []
    c_stab = []
    
    # Finds the representative year for the given stream gage
    year = str(rep_year_df['year'].loc[rep_year_df.site == row['site_id']].values[0])
    
    # Go through every year and save it in a list of dataframes
    # Massaging the timestamps of the hydropower time-series given that we are chosing the best year in terms of data completion.
    # Here, we copy the CF into a new dataframe with the time-stamps from 2012
    tmp_hydro_df_rep_year = hydro_df.loc[str(year),'capacity_factor'].copy().to_frame()
    tmp_hydro_df = base_df.copy()
    tmp_hydro_df.set_index('dateTime',inplace=True)
    tmp_hydro_df['capacity_factor'] = tmp_hydro_df_rep_year.loc[year,'capacity_factor'].values
 
    # Indexing 8760 hours
    tmp_solar_df = solar_df.loc['2012-01-01':'2012-12-30'].copy()
    
    # Re-sample the hourly data into daily values
    #tmp_hydro_df = tmp_hydro_df.resample('D').mean()
    #tmp_solar_df = tmp_solar_df.resample('D').mean()

    tmp_hydro_df.rename(columns={'capacity_factor':row['site_id']}, inplace=True)
    tmp_solar_df.rename(columns={'pv_cf':row['site_id']}, inplace=True)
    
    # Compute complementarity metrics (PV as reference)
    cf_mix_tmp, c_stab_tmp = main_stability(tmp_solar_df, tmp_hydro_df)
    cf_mix_tmp.rename(columns={row['site_id']:year}, inplace=True)

    cf_mix.append(cf_mix_tmp)
    c_stab.append(c_stab_tmp)
        
        #break
        
    cf_mix_df = pd.concat(cf_mix, axis=1)
    #cf_mix_df.to_csv(f"{cf_mix_path}/hydro-pv/{row['site_id']}.csv")
    
    c_stab_df = pd.concat(c_stab, axis=1)
    #c_stab_df.to_csv(f"{c_stab_path}/hydro-pv/{row['site_id']}.csv")
    
    annual_mean = c_stab_df.mean()
    
    annual_stab_df.loc[idx,'site_id'] = row['site_id']
    annual_stab_df.loc[idx,'lat'] = row['lat']
    annual_stab_df.loc[idx,'lon'] = row['lon']
    annual_stab_df.loc[idx,'c_stab'] = annual_mean.values[0]
    
    #break
    
    #### Pearsons
    pearsons_pv_hy.loc[idx,'site_id'] = row['site_id']
    corr, _ = pearsonr(tmp_solar_df[row['site_id']].values, tmp_hydro_df[row['site_id']].values)
    #p_cff = stability_coefficient(tmp_solar_df, tmp_hydro_df)
    pearsons_pv_hy.loc[idx,'p'] = corr
    
    #if idx == 3:
    #break
    
annual_stab_df.to_csv(f"{c_stab_path}/npd_stab_pv_hydro.csv")
pearsons_pv_hy.to_csv(f"{c_stab_path}/npd_pearson_pv_hydro.csv")
# Out:
# 0. Processing PV profile CO01656 and NPD 9019500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9019500_2016_synthetic.csv
# No data in site 9019500
# No file for site 7069220
# 2. Processing PV profile NM00003 and NPD 8328950, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8328950_2016_synthetic.csv
# No data in site 8328950
# 3. Processing PV profile PA00110 and NPD 3020000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3020000_2019_synthetic.csv

# %% [markdown]
# # Complementarity Wind-hydro

# %%
# Stability coefficient
missing_sites = []
df_missing = pd.DataFrame()

pv_wind_id_df.fillna(0, inplace=True)
# only processing data for this year
year = 2020

pearsons_wind_hy = pd.DataFrame(columns=['site_id','p'])

annual_stab_df = pd.DataFrame(columns = ['site_id', 'lat', 'lon', 'c_stab'])

for idx, row in pv_wind_id_df.iterrows():
    
    #print(type(row['post_csv_filename']))
    if row['post_csv_filename'] == 0:
        print( f"No file for site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
        
    print(f"{idx}. Processing Wind profile {row['wind_id']} and NPD {row['site_id']}, {row['post_csv_filename']}")

    wind_df = pd.read_csv(f"{wind_dest_path}/{row['wind_id']}_{wind_filename_prefix}.csv",parse_dates=True,index_col=0)
    hydro_df = pd.read_csv(row['post_csv_filename'],parse_dates=True,index_col=0)
    
    
    hydro_df.fillna(0, inplace=True)
    
    if hydro_df['capacity_factor'].sum() == 0.0:
        print( f"No data in site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
    
    cf_mix = []
    c_stab = []
    
    # Finds the representative year for the given stream gage
    year = str(rep_year_df['year'].loc[rep_year_df.site == row['site_id']].values[0])
    
    #for year in years:
    # Go through every year and save it in a list of dataframes
    # Go through every year and save it in a list of dataframes
    # Massaging the timestamps of the hydropower time-series given that we are chosing the best year in terms of data completion.
    # Here, we copy the CF into a new dataframe with the time-stamps from 2012
    tmp_hydro_df_2020 = hydro_df.loc[str(year),'capacity_factor'].copy().to_frame()
    tmp_hydro_df = base_df.copy()
    tmp_hydro_df['capacity_factor'] = tmp_hydro_df_2020.loc[year,'capacity_factor'].values
    tmp_hydro_df.set_index('dateTime',inplace=True)
    
    tmp_wind_df = wind_df.loc['2012-01-01':'2012-12-30'].copy()

    tmp_hydro_df.rename(columns={'capacity_factor':row['site_id']}, inplace=True)
    tmp_wind_df.rename(columns={'wind_cf':row['site_id']}, inplace=True)
    #tmp_wind_df.head()
    cf_mix_tmp, c_stab_tmp = main_stability(tmp_wind_df, tmp_hydro_df)
    cf_mix_tmp.rename(columns={row['site_id']:year}, inplace=True)

    cf_mix.append(cf_mix_tmp)
    c_stab.append(c_stab_tmp)
        #break
    cf_mix_df = pd.concat(cf_mix, axis=1)
    #cf_mix_df.to_csv(f"data/2000_2020_npd/cf_mix/hydro-wind/{row['site_id']}.csv")
    
    c_stab_df = pd.concat(c_stab, axis=1)
    #c_stab_df.to_csv(f"{c_stab_path}/hydro-wind/{row['site_id']}.csv")
    
    annual_mean = c_stab_df.mean()
    
    annual_stab_df.loc[idx,'site_id'] = row['site_id']
    annual_stab_df.loc[idx,'lat'] = row['lat']
    annual_stab_df.loc[idx,'lon'] = row['lon']
    annual_stab_df.loc[idx,'c_stab'] = annual_mean.values[0]
    
    #### Pearsons
    pearsons_wind_hy.loc[idx,'site_id'] = row['site_id']
    corr, _ = pearsonr(tmp_wind_df[row['site_id']].values, tmp_hydro_df[row['site_id']].values)
    
    #p_cff = stability_coefficient(tmp_hydro_df,tmp_wind_df)
    pearsons_wind_hy.loc[idx,'p'] = corr
    #pearsons_wind_hy.loc[idx,'p'] = stability_coefficient(tmp_hydro_df,tmp_wind_df)
    #break

annual_stab_df.to_csv(f"{c_stab_path}/npd_stab_wind_hydro.csv")
pearsons_wind_hy.to_csv(f"{c_stab_path}/npd_pearson_wind_hydro.csv")
# Out:
# 0. Processing Wind profile CO01656 and NPD 9019500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9019500_2016_synthetic.csv
# No data in site 9019500
# No file for site 7069220
# 2. Processing Wind profile NM00003 and NPD 8328950, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8328950_2016_synthetic.csv
# No data in site 8328950
# 3. Processing Wind profile PA00110 and NPD 3020000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3020000_2019_synthetic.csv
# 4. Processing Wind profile AL05903 and NPD 3592000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3592000_2018_synthetic.csv
# 5. Processing Wind profile NM00293 and NPD 7227000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_7227000_2015_synthetic.csv
# No data in site 7227000
# 6. Processing Wind profile TX00001 and NPD 8063800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8063800_2012_synthetic.csv
# No data in site 8063800
# 7. Processing Wind profile WY01496 and NPD 6670500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_6670500_2019_synthetic.csv
# 8. Processing Wind profile CT00583 and NPD 1184000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1184000_2010_synthetic.csv
# 9. Processing Wind profile NY00039 and NPD 1374701, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1374701_2010_synthetic.csv
# No data in site 1374701
# 10. Processing Wind profile KY03061 and NPD 3400800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3400800_2015_synthetic.csv
# 11. Processing Wind profile NY00953 and NPD 1342602, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1342602_2018_synthetic.csv
# 12. Processing Wind profile NV10153 and NPD 9419800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9419800_2014_synthetic.csv
# 13. Processing Wind profile NJ00354 and NPD 1381000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1381000_2013_synthetic.csv
# No data in site 1381000
# 14. Processing Wind profile KY01205 and NPD 3282060, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3282060_2013_synthetic.csv
# 15. Processing Wind profile NH00002 and NPD 1091500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1091500_2018_synthetic.csv
# 16. Processing Wind profile KY01203 and NPD 3282290, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3282290_2014_synthetic.csv
# 17. Processing Wind profile TX00003 and NPD 8047000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8047000_2012_synthetic.csv
# No data in site 8047000
# 18. Processing Wind profile NY00155 and NPD 1315000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1315000_2010_synthetic.csv
# 19. Processing Wind profile MI00619 and NPD 4108660, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4108660_2014_synthetic.csv
# 20. Processing Wind profile KY01201 and NPD 3284500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3284500_2012_synthetic.csv
# 21. Processing Wind profile KY01202 and NPD 3284230, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3284230_2014_synthetic.csv
# 22. Processing Wind profile LA00001 and NPD 8028000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8028000_2012_synthetic.csv
# No data in site 8028000
# 23. Processing Wind profile PA00914 and NPD 1544000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1544000_2013_synthetic.csv
# No data in site 1544000
# 24. Processing Wind profile OH00015 and NPD 3225500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3225500_2015_synthetic.csv
# No data in site 3225500
# 25. Processing Wind profile KY03002 and NPD 3321500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3321500_2015_synthetic.csv
# 26. Processing Wind profile KY01198 and NPD 3287250, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3287250_2013_synthetic.csv
# 27. Processing Wind profile NY00954 and NPD 4235600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4235600_2014_synthetic.csv
# 28. Processing Wind profile CO02140 and NPD 9239500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9239500_2015_synthetic.csv
# No data in site 9239500
# 29. Processing Wind profile AL01431 and NPD 2469761, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2469761_2014_synthetic.csv
# 30. Processing Wind profile AL01429 and NPD 2466030, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2466030_2010_synthetic.csv
# No data in site 2466030
# 31. Processing Wind profile 55 and NPD 10344500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_10344500_2014_synthetic.csv
# 32. Processing Wind profile FL00156 and NPD 2243960, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2243960_2010_synthetic.csv
# 33. Processing Wind profile AZ10316 and NPD 9512165, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9512165_2011_synthetic.csv
# No data in site 9512165
# 34. Processing Wind profile OH00388 and NPD 4192500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4192500_2014_synthetic.csv
# No data in site 4192500
# 35. Processing Wind profile MT82932 and NPD 5018000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5018000_2018_synthetic.csv
# 36. Processing Wind profile 1843 and NPD 1123600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1123600_2013_synthetic.csv
# 37. Processing Wind profile WY01383 and NPD 6227600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_6227600_2010_synthetic.csv
# No data in site 6227600
# 38. Processing Wind profile NY00046 and NPD 1375000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1375000_2014_synthetic.csv
# No data in site 1375000
# 39. Processing Wind profile IN00810 and NPD 4182900, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4182900_2015_synthetic.csv
# No data in site 4182900
# 40. Processing Wind profile AL01430 and NPD 2467000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2467000_2019_synthetic.csv
# No file for site 3284000
# 42. Processing Wind profile KY01199 and NPD 3287000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3287000_2013_synthetic.csv
# 43. Processing Wind profile KY01204 and NPD 3282120, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3282120_2014_synthetic.csv
# 44. Processing Wind profile NY00962 and NPD 1354500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1354500_2014_synthetic.csv
# 45. Processing Wind profile OH00032 and NPD 3090500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3090500_2014_synthetic.csv
# 46. Processing Wind profile OH00698 and NPD 3150000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3150000_2013_synthetic.csv
# 47. Processing Wind profile TX04101 and NPD 8096500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8096500_2010_synthetic.csv
# No data in site 8096500
# 48. Processing Wind profile IA03064 and NPD 5454500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5454500_2013_synthetic.csv
# 49. Processing Wind profile IA01320 and NPD 5464000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5464000_2013_synthetic.csv
# No data in site 5464000
# 50. Processing Wind profile PA01134 and NPD 1520000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1520000_2010_synthetic.csv
# No data in site 1520000
# 51. Processing Wind profile WV00049 and NPD 3058000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3058000_2012_synthetic.csv
# No data in site 3058000
# 52. Processing Wind profile 300 and NPD 14155500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_14155500_2011_synthetic.csv
# 53. Processing Wind profile 1230 and NPD 1328770, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1328770_2018_synthetic.csv
# 54. Processing Wind profile TX00005 and NPD 8055000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8055000_2012_synthetic.csv
# No data in site 8055000
# 55. Processing Wind profile AR00158 and NPD 7263012, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_7263012_2011_synthetic.csv
# 56. Processing Wind profile FL00145 and NPD 2238500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2238500_2016_synthetic.csv
# No data in site 2238500
# 57. Processing Wind profile PA00126 and NPD 3086000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3086000_2013_synthetic.csv
# 58. Processing Wind profile NM00500 and NPD 8401500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8401500_2018_synthetic.csv
# 59. Processing Wind profile NM00132 and NPD 8403500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8403500_2010_synthetic.csv
# 60. Processing Wind profile NC00206 and NPD 2105500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2105500_2013_synthetic.csv
# 61. Processing Wind profile CA00030 and NPD 11476500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_11476500_2011_synthetic.csv
# No data in site 11476500
# 62. Processing Wind profile IN00012 and NPD 4180500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4180500_2010_synthetic.csv
# No data in site 4180500
# 63. Processing Wind profile OR00016 and NPD 14170000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_14170000_2011_synthetic.csv
# 64. Processing Wind profile OR00013 and NPD 14162200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_14162200_2011_synthetic.csv
# 65. Processing Wind profile MT82919 and NPD 6017000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_6017000_2019_synthetic.csv
# 66. Processing Wind profile FL00169 and NPD 2304500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2304500_2012_synthetic.csv
# 67. Processing Wind profile AZ10314 and NPD 9429000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9429000_2016_synthetic.csv
# 68. Processing Wind profile KS00021 and NPD 6875900, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_6875900_2016_synthetic.csv
# 69. Processing Wind profile PA00114 and NPD 3049500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3049500_2013_synthetic.csv
# 70. Processing Wind profile PA00003 and NPD 1541200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1541200_2017_synthetic.csv
# 71. Processing Wind profile MA00963 and NPD 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1166500_2019_synthetic.csv
# 72. Processing Wind profile PA01547 and NPD 3082500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3082500_2015_synthetic.csv
# No data in site 3082500
# 73. Processing Wind profile NY00410 and NPD 4247000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4247000_2014_synthetic.csv
# 74. Processing Wind profile AL01981 and NPD 2465000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2465000_2012_synthetic.csv
# No data in site 2465000
# 75. Processing Wind profile KY03055 and NPD 3249500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3249500_2010_synthetic.csv
# /opt/anaconda3/envs/hat-env/lib/python3.6/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# 76. Processing Wind profile CT00378 and NPD 1188090, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1188090_2014_synthetic.csv
# 77. Processing Wind profile NC00182 and NPD 2105769, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2105769_2013_synthetic.csv
# 78. Processing Wind profile CO02788 and NPD 9041400, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9041400_2019_synthetic.csv
# No data in site 9041400
# 79. Processing Wind profile AZ82203 and NPD 9426000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9426000_2012_synthetic.csv
# 80. Processing Wind profile IA01213 and NPD 5463050, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5463050_2017_synthetic.csv
# 81. Processing Wind profile NY00558 and NPD 4242500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4242500_2011_synthetic.csv
# No data in site 4242500
# 82. Processing Wind profile 294 and NPD 3209000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3209000_2015_synthetic.csv
# No data in site 3209000
# 83. Processing Wind profile KY03003 and NPD 3320000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3320000_2016_synthetic.csv
# 84. Processing Wind profile 1201 and NPD 1347000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1347000_2018_synthetic.csv
# 85. Processing Wind profile PA00102 and NPD 3039000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3039000_2014_synthetic.csv
# 86. Processing Wind profile 647 and NPD 2341460, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_2341460_2014_synthetic.csv
# 87. Processing Wind profile TX01542 and NPD 8162500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8162500_2017_synthetic.csv
# No data in site 8162500
# 88. Processing Wind profile IA01270 and NPD 5464730, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5464730_2019_synthetic.csv
# 89. Processing Wind profile CO00976 and NPD 9246500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_9246500_2014_synthetic.csv
# No data in site 9246500
# 90. Processing Wind profile 898 and NPD 1153000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1153000_2018_synthetic.csv
# 91. Processing Wind profile TX05020 and NPD 8048000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8048000_2012_synthetic.csv
# No data in site 8048000
# 92. Processing Wind profile OK02537 and NPD 7241000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_7241000_2013_synthetic.csv
# No data in site 7241000
# 93. Processing Wind profile NY01211 and NPD 1500000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1500000_2017_synthetic.csv
# No data in site 1500000
# 94. Processing Wind profile PA00285 and NPD 3042500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3042500_2015_synthetic.csv
# No data in site 3042500
# 95. Processing Wind profile MI00361 and NPD 4151500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_4151500_2014_synthetic.csv
# No data in site 4151500
# 96. Processing Wind profile WV07723 and NPD 3070260, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3070260_2015_synthetic.csv
# No data in site 3070260
# No file for site 4101225
# 98. Processing Wind profile OH00005 and NPD 3124500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3124500_2015_synthetic.csv
# No data in site 3124500
# 99. Processing Wind profile PA00007 and NPD 1575500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1575500_2012_synthetic.csv
# No data in site 1575500
# 100. Processing Wind profile TX00014 and NPD 8104100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_8104100_2017_synthetic.csv
# No data in site 8104100
# 101. Processing Wind profile PA01134 and NPD 1518000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1518000_2010_synthetic.csv
# No data in site 1518000
# 102. Processing Wind profile WV10924 and NPD 3203600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3203600_2013_synthetic.csv
# No data in site 3203600
# 103. Processing Wind profile OH01102 and NPD 3111500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3111500_2013_synthetic.csv
# 104. Processing Wind profile KS00009 and NPD 6890900, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_6890900_2017_synthetic.csv
# No data in site 6890900
# 105. Processing Wind profile WV09101 and NPD 3056000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_3056000_2016_synthetic.csv
# 106. Processing Wind profile WI00296 and NPD 5430500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5430500_2016_synthetic.csv
# 107. Processing Wind profile RI00809 and NPD 1113895, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_1113895_2017_synthetic.csv
# 108. Processing Wind profile WI00589 and NPD 5378500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/npd/synthetic_profiles/npd_5378500_2018_synthetic.csv
