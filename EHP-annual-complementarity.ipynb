# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

# Local imports
from hat.utils.stability_testing import *

# %%
pv_dest_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/complementarity/pv_time_series'
wind_dest_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/complementarity/wind_time_series'
pv_filename_prefix = 'cf_pv_profile'
wind_filename_prefix = 'cf_wind_profile'

c_stab_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/complementarity/c_stab'
cf_mix_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/complementarity/cf_mix'
pearsons_path = '/Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/complementarity/pearson'

rep_year_df = pd.read_csv('../data/misc/ed_representative_year.csv')
years = range(2007,2014)

pv_wind_id_df = pd.read_csv('../data/misc/master_pv_wind_ed.csv')

# build the base dataframe with the timestamps from 2012
rng = pd.date_range(f'2012-01-01 00:00:00+00:00', periods=8760, freq='1H')
base_df = pd.DataFrame()
base_df['dateTime'] = rng

# %%
pv_wind_id_df.head(3)
# Out:
#          lat        lon                          dam_name  site_id  \
# 0  45.158051 -67.401657           Lower Saint Croix River  1021000
# 1  44.786598 -71.124901  Stearns Brook-Androscoggin River  1053500
# 2  44.456947 -71.186066  Stearns Brook-Androscoggin River  1054000
#
#                                    post_csv_filename  pv_id  wind_id
# 0  /Users/galljf/OneDrive - Idaho National Labora...   1681     1681
# 1  /Users/galljf/OneDrive - Idaho National Labora...   1178     1178
# 2  /Users/galljf/OneDrive - Idaho National Labora...    726      726

# %% [markdown]
# # Complementarity PV-Hydro

# %%
from pathlib import Path

### Stability coefficient
missing_sites = []
df_missing = pd.DataFrame()

pv_wind_id_df.fillna(0, inplace=True)

pearsons_pv_hy = pd.DataFrame(columns=['site_id','p'])
# only processing data for this year
year = 2020

annual_stab_df = pd.DataFrame(columns = ['site_id', 'lat', 'lon', 'c_stab'])

for idx, row in pv_wind_id_df.iterrows():
        
    if row['post_csv_filename'] == 0:
        print( f"No file for site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
    
    if row['site_id'] not in rep_year_df.site.values:
        print(f"Site doesn't have enough data: {row['site_id']}")
        empty_data_sites.append(row['site_id'])
        query_df.loc[idx,'post_csv_filename'] = ""
        continue
        
    print(f"{idx}. Processing PV profile {row['pv_id']} and ED {row['site_id']}, {row['post_csv_filename']}")
    
    solar_df = pd.read_csv(f"{pv_dest_path}/{row['pv_id']}_{pv_filename_prefix}.csv",parse_dates=True,index_col=0)
    hydro_df = pd.read_csv(row['post_csv_filename'],parse_dates=True,index_col=0)
    
    hydro_df.fillna(0, inplace=True)
    
    # Finds the representative year for the given stream gage
    year = str(rep_year_df['year'].loc[rep_year_df.site == row['site_id']].values[0])
    
    if len(hydro_df[year]) < 8760 or len(hydro_df[year]) > 8784:
        print("Hydro data incomplete")
        missing_sites.append(row['site_id'])
        continue
        
    if float(hydro_df['capacity_factor'].sum()) == 0.0:
        print( f"No data in site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
    
    cf_mix = []
    c_stab = []
    
    # Massaging the timestamps of the hydropower time-series given that we are chosing the best year in terms of data completion.
    # Here, we copy the CF into a new dataframe with the time-stamps from 2012
    tmp_hydro_df_rep_year = hydro_df.loc[str(year),'capacity_factor'].copy().to_frame()
    tmp_hydro_df = base_df.copy()
    tmp_hydro_df.set_index('dateTime',inplace=True)
    tmp_hydro_df['capacity_factor'] = tmp_hydro_df_rep_year.loc[year,'capacity_factor'].values
    
    # Indexing 8760 hours
    tmp_solar_df = solar_df.loc['2012-01-01':'2012-12-30'].copy()
    
    # Re-sample the hourly data into daily values
    #tmp_hydro_df = tmp_hydro_df.resample('D').mean()
    #tmp_solar_df = tmp_solar_df.resample('D').mean()

    tmp_hydro_df.rename(columns={'capacity_factor':row['site_id']}, inplace=True)
    tmp_solar_df.rename(columns={str(row['pv_id']):row['site_id']}, inplace=True)
    
    # Compute complementarity metrics (PV as reference)
    cf_mix_tmp, c_stab_tmp = main_stability(tmp_solar_df, tmp_hydro_df)
    cf_mix_tmp.rename(columns={row['site_id']:year}, inplace=True)

    cf_mix.append(cf_mix_tmp)
    c_stab.append(c_stab_tmp)
     
    cf_mix_df = pd.concat(cf_mix, axis=1)
    
    c_stab_df = pd.concat(c_stab, axis=1)
    
    annual_mean = c_stab_df.mean()
    
    annual_stab_df.loc[idx,'site_id'] = row['site_id']
    annual_stab_df.loc[idx,'lat'] = row['lat']
    annual_stab_df.loc[idx,'lon'] = row['lon']
    annual_stab_df.loc[idx,'c_stab'] = annual_mean.values[0]
    
    #### Pearsons
    pearsons_pv_hy.loc[idx,'site_id'] = row['site_id']
    corr, _ = pearsonr(tmp_solar_df[row['site_id']].values, tmp_hydro_df[row['site_id']].values)
    #p_cff = stability_coefficient(tmp_solar_df, tmp_hydro_df)
    pearsons_pv_hy.loc[idx,'p'] = corr
    

annual_stab_df.to_csv(f"{c_stab_path}/ed_stab_pv_hydro.csv", index=False)
pearsons_pv_hy.to_csv(f"{pearsons_path}/ed_pearson_pv_hydro.csv", index=False)
# Out:
# 0. Processing PV profile 1681 and ED 1021000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1021000_2010_synthetic.csv
# 1. Processing PV profile 1178 and ED 1053500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1053500_2013_synthetic.csv
# 2. Processing PV profile 726 and ED 1054000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054000_2013_synthetic.csv
# 3. Processing PV profile 726 and ED 1054000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054000_2013_synthetic.csv
# 4. Processing PV profile 726 and ED 1054000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054000_2013_synthetic.csv
# 5. Processing PV profile 780 and ED 1054500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054500_2014_synthetic.csv
# No data in site 1054500
# 6. Processing PV profile 780 and ED 1054500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054500_2014_synthetic.csv
# No data in site 1054500
# 7. Processing PV profile 1864 and ED 1081000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1081000_2014_synthetic.csv
# 8. Processing PV profile 1772 and ED 1082000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1082000_2017_synthetic.csv
# No data in site 1082000
# 9. Processing PV profile 1772 and ED 1082000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1082000_2017_synthetic.csv
# No data in site 1082000
# 10. Processing PV profile 1180 and ED 1091500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1091500_2019_synthetic.csv
# 11. Processing PV profile 1982 and ED 1094000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1094000_2019_synthetic.csv
# 12. Processing PV profile 1982 and ED 1094000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1094000_2019_synthetic.csv
# 13. Processing PV profile 1982 and ED 1094000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1094000_2019_synthetic.csv
# 14. Processing PV profile 1562 and ED 1096500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1096500_2014_synthetic.csv
# 15. Processing PV profile 1720 and ED 1100000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1100000_2014_synthetic.csv
# 16. Processing PV profile 1720 and ED 1100000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1100000_2014_synthetic.csv
# 17. Processing PV profile 1720 and ED 1100000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1100000_2014_synthetic.csv
# 18. Processing PV profile 1863 and ED 1105876, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1105876_2015_synthetic.csv
# 19. Processing PV profile 1725 and ED 1113895, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1113895_2013_synthetic.csv
# No data in site 1113895
# 20. Processing PV profile 1832 and ED 1125100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1125100_2013_synthetic.csv
# 21. Processing PV profile 1973 and ED 1135500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1135500_2014_synthetic.csv
# No data in site 1135500
# 22. Processing PV profile 256 and ED 1151500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1151500_2017_synthetic.csv
# No data in site 1151500
# 23. Processing PV profile 1840 and ED 1152010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1152010_2018_synthetic.csv
# No data in site 1152010
# 24. Processing PV profile 1355 and ED 1152500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1152500_2010_synthetic.csv
# 25. Processing PV profile 1355 and ED 1152500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1152500_2010_synthetic.csv
# 26. Processing PV profile 1992 and ED 1162000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1162000_2014_synthetic.csv
# 27. Processing PV profile 1844 and ED 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1166500_2010_synthetic.csv
# 28. Processing PV profile 1844 and ED 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1166500_2010_synthetic.csv
# 29. Processing PV profile 1844 and ED 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1166500_2010_synthetic.csv
# 30. Processing PV profile 766 and ED 1170000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1170000_2010_synthetic.csv
# No data in site 1170000
# 31. Processing PV profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 32. Processing PV profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 33. Processing PV profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 34. Processing PV profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 35. Processing PV profile 1347 and ED 1177000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1177000_2010_synthetic.csv
# No data in site 1177000
# 36. Processing PV profile 1347 and ED 1177000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1177000_2010_synthetic.csv
# No data in site 1177000
# 37. Processing PV profile 1347 and ED 1177000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1177000_2010_synthetic.csv
# No data in site 1177000
# 38. Processing PV profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 39. Processing PV profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 40. Processing PV profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 41. Processing PV profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 42. Processing PV profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 43. Processing PV profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 44. Processing PV profile 1271 and ED 1346000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1346000_2014_synthetic.csv
# No data in site 1346000
# 45. Processing PV profile 1201 and ED 1347000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1347000_2014_synthetic.csv
# 46. Processing PV profile 1218 and ED 1348000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1348000_2010_synthetic.csv
# No data in site 1348000
# 47. Processing PV profile 1037 and ED 1350180, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1350180_2013_synthetic.csv
# No data in site 1350180
# 48. Processing PV profile 1147 and ED 1367500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1367500_2013_synthetic.csv
# No data in site 1367500
# 49. Processing PV profile 1815 and ED 1371500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1371500_2013_synthetic.csv
# No data in site 1371500
# 50. Processing PV profile 1399 and ED 1559000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1559000_2010_synthetic.csv
# No data in site 1559000
# 51. Processing PV profile 912 and ED 1629500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1629500_2013_synthetic.csv
# No data in site 1629500
# 52. Processing PV profile 785 and ED 1636500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1636500_2010_synthetic.csv
# No data in site 1636500
# 53. Processing PV profile 418 and ED 2024752, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2024752_2011_synthetic.csv
# No data in site 2024752
# 54. Processing PV profile 418 and ED 2024752, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2024752_2011_synthetic.csv
# No data in site 2024752
# 55. Processing PV profile 1131 and ED 2025500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2025500_2014_synthetic.csv
# 56. Processing PV profile 778 and ED 2153551, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2153551_2016_synthetic.csv
# No data in site 2153551
# 57. Processing PV profile 778 and ED 2153551, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2153551_2016_synthetic.csv
# No data in site 2153551
# 58. Processing PV profile 1624 and ED 2163500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2163500_2014_synthetic.csv
# No data in site 2163500
# 59. Processing PV profile 438 and ED 2167000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2167000_2014_synthetic.csv
# 60. Processing PV profile 792 and ED 2181350, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181350_2015_synthetic.csv
# No data in site 2181350
# 61. Processing PV profile 792 and ED 2181350, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181350_2015_synthetic.csv
# No data in site 2181350
# 62. Processing PV profile 792 and ED 2181350, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181350_2015_synthetic.csv
# No data in site 2181350
# 63. Processing PV profile 792 and ED 2181580, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181580_2010_synthetic.csv
# No data in site 2181580
# 64. Processing PV profile 1370 and ED 2207335, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2207335_2010_synthetic.csv
# No data in site 2207335
# 65. Processing PV profile 705 and ED 2335815, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2335815_2014_synthetic.csv
# 66. Processing PV profile 2108 and ED 2364500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2364500_2010_synthetic.csv
# 67. Processing PV profile 294 and ED 3209000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3209000_2015_synthetic.csv
# 68. Processing PV profile 1146 and ED 3221000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3221000_2015_synthetic.csv
# No data in site 3221000
# 69. Processing PV profile 1597 and ED 3287000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3287000_2013_synthetic.csv
# 70. Processing PV profile 1387 and ED 3453000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3453000_2011_synthetic.csv
# No data in site 3453000
# 71. Processing PV profile 993 and ED 3503000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3503000_2011_synthetic.csv
# No data in site 3503000
# 72. Processing PV profile 984 and ED 4044003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4044003_2019_synthetic.csv
# No data in site 4044003
# 73. Processing PV profile 984 and ED 4044003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4044003_2019_synthetic.csv
# No data in site 4044003
# 74. Processing PV profile 1507 and ED 4044724, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4044724_2015_synthetic.csv
# 75. Processing PV profile 1504 and ED 4058100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4058100_2013_synthetic.csv
# No data in site 4058100
# 76. Processing PV profile 569 and ED 4062000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4062000_2015_synthetic.csv
# 77. Processing PV profile 520 and ED 4066003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066003_2015_synthetic.csv
# 78. Processing PV profile 520 and ED 4066003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066003_2015_synthetic.csv
# 79. Processing PV profile 796 and ED 4066030, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066030_2015_synthetic.csv
# 80. Processing PV profile 796 and ED 4066030, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066030_2015_synthetic.csv
# 81. Processing PV profile 977 and ED 4069500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4069500_2015_synthetic.csv
# 82. Processing PV profile 522 and ED 4071765, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4071765_2016_synthetic.csv
# 83. Processing PV profile 522 and ED 4071765, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4071765_2016_synthetic.csv
# 84. Processing PV profile 522 and ED 4071765, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4071765_2016_synthetic.csv
# 85. Processing PV profile 975 and ED 4101225, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4101225_2019_synthetic.csv
# No data in site 4101225
# 86. Processing PV profile 975 and ED 4101225, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4101225_2019_synthetic.csv
# No data in site 4101225
# 87. Processing PV profile 413 and ED 4108660, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4108660_2014_synthetic.csv
# 88. Processing PV profile 1490 and ED 4113000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4113000_2014_synthetic.csv
# 89. Processing PV profile 883 and ED 4122001, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4122001_2018_synthetic.csv
# 90. Processing PV profile 990 and ED 4124200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4124200_2015_synthetic.csv
# 91. Processing PV profile 976 and ED 4125550, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4125550_2013_synthetic.csv
# 92. Processing PV profile 864 and ED 4136500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4136500_2013_synthetic.csv
# 93. Processing PV profile 863 and ED 4137005, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4137005_2018_synthetic.csv
# 94. Processing PV profile 866 and ED 4137500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4137500_2013_synthetic.csv
# 95. Processing PV profile 866 and ED 4137500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4137500_2013_synthetic.csv
# 96. Processing PV profile 1349 and ED 4191500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4191500_2013_synthetic.csv
# No data in site 4191500
# 97. Processing PV profile 978 and ED 4231600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4231600_2015_synthetic.csv
# 98. Processing PV profile 978 and ED 4231600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4231600_2015_synthetic.csv
# 99. Processing PV profile 854 and ED 4232730, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4232730_2014_synthetic.csv
# 100. Processing PV profile 854 and ED 4232730, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4232730_2014_synthetic.csv
# 101. Processing PV profile 1775 and ED 4235440, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4235440_2013_synthetic.csv
# 102. Processing PV profile 1775 and ED 4235440, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4235440_2013_synthetic.csv
# 103. Processing PV profile 1482 and ED 4249000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4249000_2013_synthetic.csv
# 104. Processing PV profile 1525 and ED 4250200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4250200_2011_synthetic.csv
# 105. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 106. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 107. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 108. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 109. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 110. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 111. Processing PV profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 112. Processing PV profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 113. Processing PV profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 114. Processing PV profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 115. Processing PV profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 116. Processing PV profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 117. Processing PV profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 118. Processing PV profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 119. Processing PV profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 120. Processing PV profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 121. Processing PV profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 122. Processing PV profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 123. Processing PV profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 124. Processing PV profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 125. Processing PV profile 1270 and ED 4285500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4285500_2017_synthetic.csv
# 126. Processing PV profile 1270 and ED 4285500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4285500_2017_synthetic.csv
# 127. Processing PV profile 915 and ED 4290500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4290500_2010_synthetic.csv
# No data in site 4290500
# 128. Processing PV profile 677 and ED 4292500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4292500_2010_synthetic.csv
# No data in site 4292500
# 129. Processing PV profile 2173 and ED 4293000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4293000_2015_synthetic.csv
# 130. Processing PV profile 944 and ED 4294000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4294000_2015_synthetic.csv
# 131. Processing PV profile 1275 and ED 5129515, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5129515_2016_synthetic.csv
# 132. Processing PV profile 1602 and ED 5200510, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5200510_2013_synthetic.csv
# 133. Processing PV profile 931 and ED 5242300, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5242300_2013_synthetic.csv
# 134. Processing PV profile 870 and ED 5247500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5247500_2018_synthetic.csv
# 135. Processing PV profile 379 and ED 5267000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5267000_2011_synthetic.csv
# 136. Processing PV profile 1764 and ED 5270700, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5270700_2018_synthetic.csv
# 137. Processing PV profile 1123 and ED 5341752, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5341752_2013_synthetic.csv
# No data in site 5341752
# 138. Processing PV profile 1479 and ED 5342000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5342000_2013_synthetic.csv
# No data in site 5342000
# 139. Processing PV profile 1479 and ED 5342000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5342000_2013_synthetic.csv
# No data in site 5342000
# 140. Processing PV profile 1334 and ED 5355092, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5355092_2018_synthetic.csv
# 141. Processing PV profile 1871 and ED 5383075, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5383075_2010_synthetic.csv
# 142. Processing PV profile 1409 and ED 5421740, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5421740_2017_synthetic.csv
# 143. Processing PV profile 862 and ED 5442300, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5442300_2010_synthetic.csv
# No data in site 5442300
# 144. Processing PV profile 1366 and ED 5443500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5443500_2013_synthetic.csv
# 145. Processing PV profile 171 and ED 5507800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5507800_2016_synthetic.csv
# 146. Processing PV profile 737 and ED 6204070, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6204070_2013_synthetic.csv
# 147. Processing PV profile 788 and ED 6714500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6714500_2019_synthetic.csv
# 148. Processing PV profile 18 and ED 6741510, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6741510_2012_synthetic.csv
# No data in site 6741510
# 149. Processing PV profile 436 and ED 6796000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6796000_2015_synthetic.csv
# 150. Processing PV profile 388 and ED 6926000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6926000_2018_synthetic.csv
# 151. Processing PV profile 103 and ED 7083710, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_7083710_2010_synthetic.csv
# No data in site 7083710
# 152. Processing PV profile 923 and ED 7191500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_7191500_2016_synthetic.csv
# 153. Processing PV profile 305 and ED 7263450, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_7263450_2010_synthetic.csv
# 154. Processing PV profile 275 and ED 8053000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8053000_2010_synthetic.csv
# No data in site 8053000
# 155. Processing PV profile 274 and ED 8167800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8167800_2017_synthetic.csv
# 156. Processing PV profile 1628 and ED 8169845, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8169845_2019_synthetic.csv
# 157. Processing PV profile 1151 and ED 8173900, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8173900_2018_synthetic.csv
# No data in site 8173900
# 158. Processing PV profile 16 and ED 8361000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8361000_2015_synthetic.csv
# 159. Processing PV profile 1247 and ED 9050700, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9050700_2016_synthetic.csv
# 160. Processing PV profile 25 and ED 9057500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9057500_2016_synthetic.csv
# 161. Processing PV profile 1741 and ED 9079450, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9079450_2017_synthetic.csv
# 162. Processing PV profile 101 and ED 9080400, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9080400_2017_synthetic.csv
# 163. Processing PV profile 13 and ED 9128000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9128000_2016_synthetic.csv
# 164. Processing PV profile 20 and ED 9211200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9211200_2015_synthetic.csv
# 165. Processing PV profile 2048 and ED 9237500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9237500_2010_synthetic.csv
# 166. Processing PV profile 97 and ED 9353800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9353800_2014_synthetic.csv
# No data in site 9353800
# 167. Processing PV profile 22 and ED 9380000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9380000_2015_synthetic.csv
# 168. Processing PV profile 1447 and ED 9410100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9410100_2016_synthetic.csv
# No data in site 9410100
# 169. Processing PV profile 14 and ED 9423000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9423000_2012_synthetic.csv
# 170. Processing PV profile 47 and ED 9427520, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9427520_2017_synthetic.csv
# 171. Processing PV profile 1231 and ED 10113500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10113500_2012_synthetic.csv
# 172. Processing PV profile 102 and ED 10132000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10132000_2016_synthetic.csv
# 173. Processing PV profile 79 and ED 10137000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10137000_2016_synthetic.csv
# No data in site 10137000
# 174. Processing PV profile 108 and ED 10140100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10140100_2012_synthetic.csv
# 175. Processing PV profile 108 and ED 10140700, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10140700_2012_synthetic.csv
# No data in site 10140700
# 176. Processing PV profile 149 and ED 10155200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10155200_2010_synthetic.csv
# 177. Processing PV profile 416 and ED 10234500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10234500_2015_synthetic.csv
# 178. Processing PV profile 416 and ED 10234500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10234500_2015_synthetic.csv
# 179. Processing PV profile 416 and ED 10234500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10234500_2015_synthetic.csv
# 180. Processing PV profile 69 and ED 10312275, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10312275_2012_synthetic.csv
# 181. Processing PV profile 55 and ED 10344500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10344500_2013_synthetic.csv
# 182. Processing PV profile 270 and ED 11465200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_11465200_2012_synthetic.csv
# No data in site 11465200

# %% [markdown]
# # Complementarity Wind-hydro

# %%
from pathlib import Path

### Stability coefficient
missing_sites = []
df_missing = pd.DataFrame()

pv_wind_id_df.fillna(0, inplace=True)

pearsons_wind_hy = pd.DataFrame(columns=['site_id','p'])
# only processing data for this year
year = 2020

annual_stab_df = pd.DataFrame(columns = ['site_id', 'lat', 'lon', 'c_stab'])

for idx, row in pv_wind_id_df.iterrows():
        
    if row['post_csv_filename'] == 0:
        print( f"No file for site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
    
    if row['site_id'] not in rep_year_df.site.values:
        print(f"Site doesn't have enough data: {row['site_id']}")
        empty_data_sites.append(row['site_id'])
        query_df.loc[idx,'post_csv_filename'] = ""
        continue
        
    print(f"{idx}. Processing Wind profile {row['wind_id']} and ED {row['site_id']}, {row['post_csv_filename']}")
    
    wind_df = pd.read_csv(f"{wind_dest_path}/{row['wind_id']}_{wind_filename_prefix}.csv",parse_dates=True,index_col=0)
    hydro_df = pd.read_csv(row['post_csv_filename'],parse_dates=True,index_col=0)
    
    hydro_df.fillna(0, inplace=True)
    
    # Finds the representative year for the given stream gage
    year = str(rep_year_df['year'].loc[rep_year_df.site == row['site_id']].values[0])
    
    if len(hydro_df[year]) < 8760 or len(hydro_df[year]) > 8784:
        print("Hydro data incomplete")
        missing_sites.append(row['site_id'])
        continue
        
    if float(hydro_df['capacity_factor'].sum()) == 0.0:
        print( f"No data in site {row['site_id']} ")
        missing_sites.append(row['site_id'])
        continue
    
    cf_mix = []
    c_stab = []
    
    # Massaging the timestamps of the hydropower time-series given that we are chosing the best year in terms of data completion.
    # Here, we copy the CF into a new dataframe with the time-stamps from 2012
    tmp_hydro_df_rep_year = hydro_df.loc[str(year),'capacity_factor'].copy().to_frame()
    tmp_hydro_df = base_df.copy()
    tmp_hydro_df.set_index('dateTime',inplace=True)
    tmp_hydro_df['capacity_factor'] = tmp_hydro_df_rep_year.loc[year,'capacity_factor'].values
    
    # Indexing 8760 hours
    tmp_wind_df = wind_df.loc['2012-01-01':'2012-12-30'].copy()
    
    # Re-sample the hourly data into daily values
    #tmp_hydro_df = tmp_hydro_df.resample('D').mean()
    #tmp_wind_df = tmp_wind_df.resample('D').mean()

    tmp_hydro_df.rename(columns={'capacity_factor':row['site_id']}, inplace=True)
    tmp_wind_df.rename(columns={str(row['wind_id']):row['site_id']}, inplace=True)
    
    # Compute complementarity metrics (wind as reference)
    cf_mix_tmp, c_stab_tmp = main_stability(tmp_wind_df, tmp_hydro_df)
    cf_mix_tmp.rename(columns={row['site_id']:year}, inplace=True)

    cf_mix.append(cf_mix_tmp)
    c_stab.append(c_stab_tmp)
     
    cf_mix_df = pd.concat(cf_mix, axis=1)
    
    c_stab_df = pd.concat(c_stab, axis=1)
    
    annual_mean = c_stab_df.mean()
    
    annual_stab_df.loc[idx,'site_id'] = row['site_id']
    annual_stab_df.loc[idx,'lat'] = row['lat']
    annual_stab_df.loc[idx,'lon'] = row['lon']
    annual_stab_df.loc[idx,'c_stab'] = annual_mean.values[0]
    
    #### Pearsons
    pearsons_wind_hy.loc[idx,'site_id'] = row['site_id']
    corr, _ = pearsonr(tmp_wind_df[row['site_id']].values, tmp_hydro_df[row['site_id']].values)
    #p_cff = stability_coefficient(tmp_wind_df, tmp_hydro_df)
    pearsons_wind_hy.loc[idx,'p'] = corr
    

annual_stab_df.to_csv(f"{c_stab_path}/ed_stab_wind_hydro.csv", index=False)
pearsons_wind_hy.to_csv(f"{pearsons_path}/ed_pearson_wind_hydro.csv", index=False)
# Out:
# 0. Processing Wind profile 1681 and ED 1021000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1021000_2010_synthetic.csv
# 1. Processing Wind profile 1178 and ED 1053500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1053500_2013_synthetic.csv
# 2. Processing Wind profile 726 and ED 1054000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054000_2013_synthetic.csv
# 3. Processing Wind profile 726 and ED 1054000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054000_2013_synthetic.csv
# 4. Processing Wind profile 726 and ED 1054000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054000_2013_synthetic.csv
# 5. Processing Wind profile 780 and ED 1054500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054500_2014_synthetic.csv
# No data in site 1054500
# 6. Processing Wind profile 780 and ED 1054500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1054500_2014_synthetic.csv
# No data in site 1054500
# 7. Processing Wind profile 1864 and ED 1081000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1081000_2014_synthetic.csv
# 8. Processing Wind profile 1772 and ED 1082000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1082000_2017_synthetic.csv
# No data in site 1082000
# 9. Processing Wind profile 1772 and ED 1082000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1082000_2017_synthetic.csv
# No data in site 1082000
# 10. Processing Wind profile 1180 and ED 1091500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1091500_2019_synthetic.csv
# 11. Processing Wind profile 1982 and ED 1094000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1094000_2019_synthetic.csv
# 12. Processing Wind profile 1982 and ED 1094000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1094000_2019_synthetic.csv
# 13. Processing Wind profile 1982 and ED 1094000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1094000_2019_synthetic.csv
# 14. Processing Wind profile 1562 and ED 1096500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1096500_2014_synthetic.csv
# 15. Processing Wind profile 1720 and ED 1100000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1100000_2014_synthetic.csv
# 16. Processing Wind profile 1720 and ED 1100000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1100000_2014_synthetic.csv
# 17. Processing Wind profile 1720 and ED 1100000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1100000_2014_synthetic.csv
# 18. Processing Wind profile 1863 and ED 1105876, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1105876_2015_synthetic.csv
# 19. Processing Wind profile 1725 and ED 1113895, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1113895_2013_synthetic.csv
# No data in site 1113895
# 20. Processing Wind profile 1832 and ED 1125100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1125100_2013_synthetic.csv
# 21. Processing Wind profile 1973 and ED 1135500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1135500_2014_synthetic.csv
# No data in site 1135500
# 22. Processing Wind profile 256 and ED 1151500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1151500_2017_synthetic.csv
# No data in site 1151500
# 23. Processing Wind profile 1840 and ED 1152010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1152010_2018_synthetic.csv
# No data in site 1152010
# 24. Processing Wind profile 1355 and ED 1152500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1152500_2010_synthetic.csv
# 25. Processing Wind profile 1355 and ED 1152500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1152500_2010_synthetic.csv
# 26. Processing Wind profile 1992 and ED 1162000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1162000_2014_synthetic.csv
# 27. Processing Wind profile 1844 and ED 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1166500_2010_synthetic.csv
# 28. Processing Wind profile 1844 and ED 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1166500_2010_synthetic.csv
# 29. Processing Wind profile 1844 and ED 1166500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1166500_2010_synthetic.csv
# 30. Processing Wind profile 766 and ED 1170000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1170000_2010_synthetic.csv
# No data in site 1170000
# 31. Processing Wind profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 32. Processing Wind profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 33. Processing Wind profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 34. Processing Wind profile 534 and ED 1172010, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1172010_2010_synthetic.csv
# 35. Processing Wind profile 1347 and ED 1177000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1177000_2010_synthetic.csv
# No data in site 1177000
# 36. Processing Wind profile 1347 and ED 1177000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1177000_2010_synthetic.csv
# No data in site 1177000
# 37. Processing Wind profile 1347 and ED 1177000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1177000_2010_synthetic.csv
# No data in site 1177000
# 38. Processing Wind profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 39. Processing Wind profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 40. Processing Wind profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 41. Processing Wind profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 42. Processing Wind profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 43. Processing Wind profile 816 and ED 1327750, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1327750_2013_synthetic.csv
# 44. Processing Wind profile 1271 and ED 1346000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1346000_2014_synthetic.csv
# No data in site 1346000
# 45. Processing Wind profile 1201 and ED 1347000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1347000_2014_synthetic.csv
# 46. Processing Wind profile 1218 and ED 1348000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1348000_2010_synthetic.csv
# No data in site 1348000
# 47. Processing Wind profile 1037 and ED 1350180, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1350180_2013_synthetic.csv
# No data in site 1350180
# 48. Processing Wind profile 1147 and ED 1367500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1367500_2013_synthetic.csv
# No data in site 1367500
# 49. Processing Wind profile 1815 and ED 1371500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1371500_2013_synthetic.csv
# No data in site 1371500
# 50. Processing Wind profile 1399 and ED 1559000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1559000_2010_synthetic.csv
# No data in site 1559000
# 51. Processing Wind profile 912 and ED 1629500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1629500_2013_synthetic.csv
# No data in site 1629500
# 52. Processing Wind profile 785 and ED 1636500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_1636500_2010_synthetic.csv
# No data in site 1636500
# 53. Processing Wind profile 418 and ED 2024752, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2024752_2011_synthetic.csv
# No data in site 2024752
# 54. Processing Wind profile 418 and ED 2024752, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2024752_2011_synthetic.csv
# No data in site 2024752
# 55. Processing Wind profile 1131 and ED 2025500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2025500_2014_synthetic.csv
# 56. Processing Wind profile 778 and ED 2153551, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2153551_2016_synthetic.csv
# No data in site 2153551
# 57. Processing Wind profile 778 and ED 2153551, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2153551_2016_synthetic.csv
# No data in site 2153551
# 58. Processing Wind profile 1624 and ED 2163500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2163500_2014_synthetic.csv
# No data in site 2163500
# 59. Processing Wind profile 438 and ED 2167000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2167000_2014_synthetic.csv
# 60. Processing Wind profile 792 and ED 2181350, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181350_2015_synthetic.csv
# No data in site 2181350
# 61. Processing Wind profile 792 and ED 2181350, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181350_2015_synthetic.csv
# No data in site 2181350
# 62. Processing Wind profile 792 and ED 2181350, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181350_2015_synthetic.csv
# No data in site 2181350
# 63. Processing Wind profile 792 and ED 2181580, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2181580_2010_synthetic.csv
# No data in site 2181580
# 64. Processing Wind profile 1370 and ED 2207335, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2207335_2010_synthetic.csv
# No data in site 2207335
# 65. Processing Wind profile 705 and ED 2335815, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2335815_2014_synthetic.csv
# 66. Processing Wind profile 2108 and ED 2364500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_2364500_2010_synthetic.csv
# 67. Processing Wind profile 294 and ED 3209000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3209000_2015_synthetic.csv
# 68. Processing Wind profile 1146 and ED 3221000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3221000_2015_synthetic.csv
# No data in site 3221000
# 69. Processing Wind profile 1597 and ED 3287000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3287000_2013_synthetic.csv
# 70. Processing Wind profile 1387 and ED 3453000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3453000_2011_synthetic.csv
# No data in site 3453000
# 71. Processing Wind profile 993 and ED 3503000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_3503000_2011_synthetic.csv
# No data in site 3503000
# 72. Processing Wind profile 984 and ED 4044003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4044003_2019_synthetic.csv
# No data in site 4044003
# 73. Processing Wind profile 984 and ED 4044003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4044003_2019_synthetic.csv
# No data in site 4044003
# 74. Processing Wind profile 1507 and ED 4044724, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4044724_2015_synthetic.csv
# 75. Processing Wind profile 1504 and ED 4058100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4058100_2013_synthetic.csv
# No data in site 4058100
# 76. Processing Wind profile 569 and ED 4062000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4062000_2015_synthetic.csv
# 77. Processing Wind profile 520 and ED 4066003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066003_2015_synthetic.csv
# 78. Processing Wind profile 520 and ED 4066003, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066003_2015_synthetic.csv
# 79. Processing Wind profile 796 and ED 4066030, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066030_2015_synthetic.csv
# 80. Processing Wind profile 796 and ED 4066030, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4066030_2015_synthetic.csv
# 81. Processing Wind profile 977 and ED 4069500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4069500_2015_synthetic.csv
# 82. Processing Wind profile 522 and ED 4071765, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4071765_2016_synthetic.csv
# 83. Processing Wind profile 522 and ED 4071765, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4071765_2016_synthetic.csv
# 84. Processing Wind profile 522 and ED 4071765, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4071765_2016_synthetic.csv
# 85. Processing Wind profile 975 and ED 4101225, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4101225_2019_synthetic.csv
# No data in site 4101225
# 86. Processing Wind profile 975 and ED 4101225, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4101225_2019_synthetic.csv
# No data in site 4101225
# 87. Processing Wind profile 413 and ED 4108660, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4108660_2014_synthetic.csv
# 88. Processing Wind profile 1490 and ED 4113000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4113000_2014_synthetic.csv
# 89. Processing Wind profile 883 and ED 4122001, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4122001_2018_synthetic.csv
# 90. Processing Wind profile 990 and ED 4124200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4124200_2015_synthetic.csv
# 91. Processing Wind profile 976 and ED 4125550, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4125550_2013_synthetic.csv
# 92. Processing Wind profile 864 and ED 4136500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4136500_2013_synthetic.csv
# 93. Processing Wind profile 863 and ED 4137005, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4137005_2018_synthetic.csv
# 94. Processing Wind profile 866 and ED 4137500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4137500_2013_synthetic.csv
# 95. Processing Wind profile 866 and ED 4137500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4137500_2013_synthetic.csv
# 96. Processing Wind profile 1349 and ED 4191500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4191500_2013_synthetic.csv
# No data in site 4191500
# 97. Processing Wind profile 978 and ED 4231600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4231600_2015_synthetic.csv
# 98. Processing Wind profile 978 and ED 4231600, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4231600_2015_synthetic.csv
# 99. Processing Wind profile 854 and ED 4232730, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4232730_2014_synthetic.csv
# 100. Processing Wind profile 854 and ED 4232730, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4232730_2014_synthetic.csv
# 101. Processing Wind profile 1775 and ED 4235440, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4235440_2013_synthetic.csv
# 102. Processing Wind profile 1775 and ED 4235440, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4235440_2013_synthetic.csv
# 103. Processing Wind profile 1482 and ED 4249000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4249000_2013_synthetic.csv
# 104. Processing Wind profile 1525 and ED 4250200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4250200_2011_synthetic.csv
# 105. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 106. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 107. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 108. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 109. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 110. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 111. Processing Wind profile 1015 and ED 4258000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4258000_2018_synthetic.csv
# 112. Processing Wind profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 113. Processing Wind profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 114. Processing Wind profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 115. Processing Wind profile 1059 and ED 4262000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4262000_2013_synthetic.csv
# 116. Processing Wind profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 117. Processing Wind profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 118. Processing Wind profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 119. Processing Wind profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 120. Processing Wind profile 1076 and ED 4273500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4273500_2018_synthetic.csv
# 121. Processing Wind profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 122. Processing Wind profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 123. Processing Wind profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 124. Processing Wind profile 861 and ED 4282000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4282000_2014_synthetic.csv
# 125. Processing Wind profile 1270 and ED 4285500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4285500_2017_synthetic.csv
# 126. Processing Wind profile 1270 and ED 4285500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4285500_2017_synthetic.csv
# 127. Processing Wind profile 915 and ED 4290500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4290500_2010_synthetic.csv
# No data in site 4290500
# 128. Processing Wind profile 677 and ED 4292500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4292500_2010_synthetic.csv
# No data in site 4292500
# 129. Processing Wind profile 2173 and ED 4293000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4293000_2015_synthetic.csv
# 130. Processing Wind profile 944 and ED 4294000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_4294000_2015_synthetic.csv
# 131. Processing Wind profile 1275 and ED 5129515, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5129515_2016_synthetic.csv
# 132. Processing Wind profile 1602 and ED 5200510, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5200510_2013_synthetic.csv
# 133. Processing Wind profile 931 and ED 5242300, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5242300_2013_synthetic.csv
# 134. Processing Wind profile 870 and ED 5247500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5247500_2018_synthetic.csv
# 135. Processing Wind profile 379 and ED 5267000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5267000_2011_synthetic.csv
# 136. Processing Wind profile 1764 and ED 5270700, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5270700_2018_synthetic.csv
# 137. Processing Wind profile 1123 and ED 5341752, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5341752_2013_synthetic.csv
# No data in site 5341752
# 138. Processing Wind profile 1479 and ED 5342000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5342000_2013_synthetic.csv
# No data in site 5342000
# 139. Processing Wind profile 1479 and ED 5342000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5342000_2013_synthetic.csv
# No data in site 5342000
# 140. Processing Wind profile 1334 and ED 5355092, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5355092_2018_synthetic.csv
# 141. Processing Wind profile 1871 and ED 5383075, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5383075_2010_synthetic.csv
# 142. Processing Wind profile 1409 and ED 5421740, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5421740_2017_synthetic.csv
# 143. Processing Wind profile 862 and ED 5442300, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5442300_2010_synthetic.csv
# No data in site 5442300
# 144. Processing Wind profile 1366 and ED 5443500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5443500_2013_synthetic.csv
# 145. Processing Wind profile 171 and ED 5507800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_5507800_2016_synthetic.csv
# 146. Processing Wind profile 737 and ED 6204070, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6204070_2013_synthetic.csv
# 147. Processing Wind profile 788 and ED 6714500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6714500_2019_synthetic.csv
# 148. Processing Wind profile 18 and ED 6741510, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6741510_2012_synthetic.csv
# No data in site 6741510
# 149. Processing Wind profile 436 and ED 6796000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6796000_2015_synthetic.csv
# 150. Processing Wind profile 388 and ED 6926000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_6926000_2018_synthetic.csv
# 151. Processing Wind profile 103 and ED 7083710, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_7083710_2010_synthetic.csv
# No data in site 7083710
# 152. Processing Wind profile 923 and ED 7191500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_7191500_2016_synthetic.csv
# 153. Processing Wind profile 305 and ED 7263450, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_7263450_2010_synthetic.csv
# 154. Processing Wind profile 275 and ED 8053000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8053000_2010_synthetic.csv
# No data in site 8053000
# 155. Processing Wind profile 274 and ED 8167800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8167800_2017_synthetic.csv
# 156. Processing Wind profile 1628 and ED 8169845, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8169845_2019_synthetic.csv
# 157. Processing Wind profile 1151 and ED 8173900, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8173900_2018_synthetic.csv
# No data in site 8173900
# 158. Processing Wind profile 16 and ED 8361000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_8361000_2015_synthetic.csv
# 159. Processing Wind profile 1247 and ED 9050700, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9050700_2016_synthetic.csv
# 160. Processing Wind profile 25 and ED 9057500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9057500_2016_synthetic.csv
# 161. Processing Wind profile 1741 and ED 9079450, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9079450_2017_synthetic.csv
# 162. Processing Wind profile 101 and ED 9080400, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9080400_2017_synthetic.csv
# 163. Processing Wind profile 13 and ED 9128000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9128000_2016_synthetic.csv
# 164. Processing Wind profile 20 and ED 9211200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9211200_2015_synthetic.csv
# 165. Processing Wind profile 2048 and ED 9237500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9237500_2010_synthetic.csv
# 166. Processing Wind profile 97 and ED 9353800, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9353800_2014_synthetic.csv
# No data in site 9353800
# 167. Processing Wind profile 22 and ED 9380000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9380000_2015_synthetic.csv
# 168. Processing Wind profile 1447 and ED 9410100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9410100_2016_synthetic.csv
# No data in site 9410100
# 169. Processing Wind profile 14 and ED 9423000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9423000_2012_synthetic.csv
# 170. Processing Wind profile 47 and ED 9427520, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_9427520_2017_synthetic.csv
# 171. Processing Wind profile 422 and ED 10113500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10113500_2012_synthetic.csv
# 172. Processing Wind profile 102 and ED 10132000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10132000_2016_synthetic.csv
# 173. Processing Wind profile 79 and ED 10137000, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10137000_2016_synthetic.csv
# No data in site 10137000
# 174. Processing Wind profile 108 and ED 10140100, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10140100_2012_synthetic.csv
# 175. Processing Wind profile 108 and ED 10140700, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10140700_2012_synthetic.csv
# No data in site 10140700
# 176. Processing Wind profile 149 and ED 10155200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10155200_2010_synthetic.csv
# 177. Processing Wind profile 416 and ED 10234500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10234500_2015_synthetic.csv
# 178. Processing Wind profile 416 and ED 10234500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10234500_2015_synthetic.csv
# 179. Processing Wind profile 416 and ED 10234500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10234500_2015_synthetic.csv
# 180. Processing Wind profile 69 and ED 10312275, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10312275_2012_synthetic.csv
# 181. Processing Wind profile 55 and ED 10344500, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_10344500_2013_synthetic.csv
# 182. Processing Wind profile 270 and ED 11465200, /Users/galljf/OneDrive - Idaho National Laboratory/code/hat/data/existing_plants/synthetic_profiles/ed_11465200_2012_synthetic.csv
# No data in site 11465200
